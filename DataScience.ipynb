# %% [markdown]
# <a href="https://colab.research.google.com/github/Dorcas-coder/Demo/blob/main/DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head(7)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# ...

# %%
data.tail(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class  who  \
# 889         1       1  male  26.0      0      0  30.00        C  First  man
# 890         0       3  male  32.0      0      0   7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 889        True    C   Cherbourg   yes   True
# 890        True  NaN  Queenstown    no   True

# %%
sampleA = data.sample(10, random_state =1)

# %%
data[:7]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# ...

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
sampleA.index
# Out:
# Index([514, 181, 77, 572, 442, 414, 312, 314, 73, 19], dtype='int64')

# %%
data.shape
# Out:
# (891, 15)

# %%
data.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.size
data.shape
data.shape[0]*data.shape[1] ==data.size
# Out:
# True

# %%
data['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
data.fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
data[['class','who','adult_male']]
# Out:
#       class    who  adult_male
# 0     Third    man        True
# 1     First  woman       False
# 2     Third  woman       False
# 3     First  woman       False
# 4     Third    man        True
# ..      ...    ...         ...
# 886  Second    man        True
# 887   First  woman       False
# 888   Third  woman       False
# 889   First    man        True
# 890   Third    man        True
#
# [891 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
Avg=sum(data.age)/len(data.age)
Avg
# Out:
# nan

# %%
data.age.mean()
# Out:
# 29.69911764705882

# %%
data.age.median()
# Out:
# 28.0

# %%
data.age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
data.isnull().sum().sum()
# Out:
# 869

# %%
clean_age =data.age.dropna()
sum(clean_age)/len(clean_age)==data.age.mean()
# Out:
# True

# %%
filter_fare=data[data.fare>50]
filter_fare
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
condition =data['age']>18
data[condition].sort_values(by='age',ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1    male  80.0      0      0  30.0000        S   First
# 851         0       3    male  74.0      0      0   7.7750        S   Third
# 493         0       1    male  71.0      0      0  49.5042        C   First
# 96          0       1    male  71.0      0      0  34.6542        C   First
# 116         0       3    male  70.5      0      0   7.7500        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 575         0       3    male  19.0      0      0  14.5000        S   Third
# 566         0       3    male  19.0      0      0   7.8958        S   Third
# 67          0       3    male  19.0      0      0   8.1583        S   Third
# 546         1       2  female  19.0      1      0  26.0000        S  Second
# 302         0       3    male  19.0      0      0   0.0000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
conditional=data['fare']>50
data[conditional].sort_values(by='fare',ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 35          0       1    male  42.0      1      0   52.0000        S  First
# 457         1       1  female   NaN      1      0   51.8625        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 571         1       1  female  53.0      2      0   51.4792        S  First
# 867         0       1    male  31.0      0      0   50.4958        S  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
c= data.drop(data[data['fare']<=50].index)
c.sort_values(by='fare',ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 35          0       1    male  42.0      1      0   52.0000        S  First
# 457         1       1  female   NaN      1      0   51.8625        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 571         1       1  female  53.0      2      0   51.4792        S  First
# 867         0       1    male  31.0      0      0   50.4958        S  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
data.groupby('who')['age'].mean()
# Out:
# who
# child     6.369518
# man      33.173123
# woman    32.000000
# Name: age, dtype: float64

# %%
data.groupby('class')['fare'].mean()
# Out:
# <ipython-input-34-4202e11d5712>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('class')['fare'].mean()
# class
# First     84.154687
# Second    20.662183
# Third     13.675550
# Name: fare, dtype: float64

# %%
data.groupby('class')['age'].mean()
# Out:
# <ipython-input-35-188f6ef1a07c>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('class')['age'].mean()
# class
# First     38.233441
# Second    29.877630
# Third     25.140620
# Name: age, dtype: float64

# %%
data.groupby('class')[['age','fare']].mean()
# Out:
# <ipython-input-36-e3a748c0f24c>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('class')[['age','fare']].mean()
#               age       fare
# class
# First   38.233441  84.154687
# Second  29.877630  20.662183
# Third   25.140620  13.675550

# %%
data.groupby('class',observed=False)[['age','fare']].mean()
# Out:
#               age       fare
# class
# First   38.233441  84.154687
# Second  29.877630  20.662183
# Third   25.140620  13.675550

# %%
age_groups=['0-17','18-40','41-60','60+']

# %%
data['age_group']= pd.cut(data['age'], bins=[0,17,40,60,100], labels=age_groups)

# %%
first = data.loc[data['class']=='First']
second = data.loc[data['class']=='Second']
third = data.loc[data['class']=='Third']

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.age.median()
# Out:
# 28.0

# %%
data.age + data.fare
# Out:
# 0       29.2500
# 1      109.2833
# 2       33.9250
# 3       88.1000
# 4       43.0500
#          ...
# 886     40.0000
# 887     49.0000
# 888         NaN
# 889     56.0000
# 890     39.7500
# Length: 891, dtype: float64

# %%
filter_fare=data[data.fare>50].sort_values(by='fare',ascending=False)
filter_fare
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 35          0       1    male  42.0      1      0   52.0000        S  First
# 457         1       1  female   NaN      1      0   51.8625        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 571         1       1  female  53.0      2      0   51.4792        S  First
# 867         0       1    male  31.0      0      0   50.4958        S  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.groupby("who").agg({'fare':'mean'})
# Out:
#             fare
# who
# child  32.785795
# man    24.864182
# woman  46.570711

# %%
data.groupby('who')['survived'].mean()
# Out:
# who
# child    0.590361
# man      0.163873
# woman    0.756458
# Name: survived, dtype: float64
